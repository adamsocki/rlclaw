# %% [markdown]
# # rlclaw — Notebook 01
#
# Comma Controls Challenge — GPU experiment notebook.
# **Notebook ID:** 01 | **Max runtime:** 15 minutes
#
# This notebook is managed by the agent pool system.
# Do not edit manually while an experiment is running.

# %%
# === SETUP (do not modify) ===
import time
_start = time.time()
_TIMEOUT = 15 * 60  # 15 minute hard limit

def check_timeout():
    elapsed = time.time() - _start
    if elapsed > _TIMEOUT:
        raise TimeoutError(f'Experiment exceeded 15 min limit ({elapsed/60:.1f} min)')
    return f'{elapsed/60:.1f} min elapsed, {(_TIMEOUT - elapsed)/60:.1f} min remaining'

import torch
print(f'GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only"}')
print(f'CUDA: {torch.cuda.is_available()}')
print(f'Notebook: 01')

# %%
# === DEPENDENCIES ===
# !pip install -q onnxruntime numpy pandas torch matplotlib tqdm

# %%
# === EXPERIMENT CODE ===
# This cell will be written by the agent before each experiment.
# It must:
#   1. Call check_timeout() periodically during training
#   2. Save checkpoints to /content/drive/MyDrive/rlclaw/checkpoints/
#   3. Print clear metrics at the end

print('Experiment cell — waiting for agent to populate')
check_timeout()

# %%
# === RESULTS SUMMARY ===
elapsed = time.time() - _start
print(f'\n=== EXPERIMENT COMPLETE ===')
print(f'Total time: {elapsed/60:.1f} minutes')
print(f'Within limit: {elapsed < _TIMEOUT}')
